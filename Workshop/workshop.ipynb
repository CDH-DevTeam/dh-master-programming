# %%
import requests
import pandas as pd
import json

# %% [markdown]
# ## Example without parameters
# The following example uses the Wikipedia REST API to get data, but takes no parameters. You can find documentation for the API here: https://en.wikipedia.org/api/rest_v1/#/Page%20content/get_page_summary__title_

# %%
base_url = "en.wikipedia.org/api/rest_v1"

title = "Humanities"
endpoint_url = "page/summary/" + title

url = "https://" + base_url + "/" + endpoint_url 
results = requests.get(url).json()

with open('data.json', 'w') as f:
    json.dump(results, f, indent=4)

results
# Out:
# {'type': 'standard',
#  'title': 'Humanities',
#  'displaytitle': '<span class="mw-page-title-main">Humanities</span>',
#  'namespace': {'id': 0, 'text': ''},
#  'wikibase_item': 'Q80083',
#  'titles': {'canonical': 'Humanities',
#   'normalized': 'Humanities',
#   'display': '<span class="mw-page-title-main">Humanities</span>'},
#  'pageid': 53132,
#  'thumbnail': {'source': 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/7d/Head_Platon_Glyptothek_Munich_548.jpg/230px-Head_Platon_Glyptothek_Munich_548.jpg',
#   'width': 230,
#   'height': 320},
#  'originalimage': {'source': 'https://upload.wikimedia.org/wikipedia/commons/7/7d/Head_Platon_Glyptothek_Munich_548.jpg',
#   'width': 1619,
#   'height': 2251},
#  'lang': 'en',
#  'dir': 'ltr',
#  'revision': '1122287514',
#  'tid': 'a300a810-699b-11ed-adfe-afc962565759',
#  'timestamp': '2022-11-16T20:34:04Z',
#  'description': 'Academic disciplines that study society and culture',
#  'description_source': 'local',
#  'content_urls': {'desktop': {'page': 'https://en.wikipedia.org/wiki/Humanities',
#    'revisions': 'https://en.wikipedia.org/wiki/Humanities?action=history',
#    'edit': 'https://en.wikipedia.org/wiki/Humanities?action=edit',
#    'talk': 'https://en.wikipedia.org/wiki/Talk:Humanities'},
#   'mobile': {'page': 'https://en.m.wikipedia.org/wiki/Humanities',
#    'revisions': 'https://en.m.wikipedia.org/wiki/Special:History/Humanities',
#    'edit': 'https://en.m.wikipedia.org/wiki/Humanities?action=edit',
#    'talk': 'https://en.m.wikipedia.org/wiki/Talk:Humanities'}},
#  'extract': 'Humanities are academic disciplines that study aspects of human society and culture. In the Renaissance, the term contrasted with divinity and referred to what is now called classics, the main area of secular study in universities at the time. Today, the humanities are more frequently defined as any fields of study outside of professional training, mathematics, and the natural and social sciences. They use methods that are primarily critical, or speculative, and have a significant historical element—as distinguished from the mainly empirical approaches of the natural sciences; yet, unlike the sciences, the humanities have no general history.',
#  'extract_html': '<p><b>Humanities</b> are academic disciplines that study aspects of human society and culture. In the Renaissance, the term contrasted with divinity and referred to what is now called classics, the main area of secular study in universities at the time. Today, the humanities are more frequently defined as any fields of study outside of professional training, mathematics, and the natural and social sciences. They use methods that are primarily critical, or speculative, and have a significant historical element—as distinguished from the mainly empirical approaches of the natural sciences; yet, unlike the sciences, the humanities have no general history.</p>'}

# %% [markdown]
# ## Example with parameters: Diana
# The following example uses the Diana, the CDH data API, to fetch the placenames in a certain language from the Rwanda database. We first retrieve a list of the IDs of the languages to pass to the names endpoint.
#
#
# The documentation is available at https://diana.dh.gu.se/rwanda/api/documentation/#tag/api/operation/listNames

# %%
base_url = "diana.dh.gu.se/rwanda/api/"
endpoint_url = "language/"
url = "https://" + base_url + "/" + endpoint_url 

results = requests.get(url).json()

with open('data.json', 'w') as f:
    json.dump(results, f, indent=4)


results
# Out:
# {'count': 5,
#  'next': None,
#  'previous': None,
#  'results': [{'id': 1,
#    'created_at': '2022-11-07T13:34:35.048349Z',
#    'updated_at': '2022-11-07T13:34:35.048362Z',
#    'published': True,
#    'name': 'English',
#    'abbreviation': 'en'},
#   {'id': 2,
#    'created_at': '2022-11-07T13:34:35.049080Z',
#    'updated_at': '2022-11-07T13:34:35.049085Z',
#    'published': True,
#    'name': 'French',
#    'abbreviation': 'fr'},
#   {'id': 3,
#    'created_at': '2022-11-07T13:34:35.050289Z',
#    'updated_at': '2022-11-07T13:34:35.050297Z',
#    'published': True,
#    'name': 'Kinyarwanda',
#    'abbreviation': 'rw'},
#   {'id': 4,
#    'created_at': '2022-11-07T13:34:35.051203Z',
#    'updated_at': '2022-11-07T13:34:35.051208Z',
#    'published': True,
#    'name': 'Kiswahili',
#    'abbreviation': 'sw'},
#   {'id': 5,
#    'created_at': '2022-11-21T12:29:58.191045Z',
#    'updated_at': '2022-11-21T12:29:58.191058Z',
#    'published': True,
#    'name': 'Others',
#    'abbreviation': 'others'}]}

# %%
base_url = "diana.dh.gu.se/rwanda/api/"
endpoint_url = "name/"
url = "https://" + base_url + "/" + endpoint_url 

params = {
    'languages': 2,
    'limit': 5,
}

results = requests.get(url, params=params).json()

with open('data.json', 'w') as f:
    json.dump(results, f, indent=4)


results
# Out:
# {'count': 85,
#  'next': 'http://diana.dh.gu.se/rwanda/api/name/?languages=2&limit=5&offset=5',
#  'previous': None,
#  'results': [{'id': 176,
#    'created_at': '2022-11-07T13:34:37.647130Z',
#    'updated_at': '2022-11-07T13:34:37.647869Z',
#    'published': True,
#    'text': 'Avenue KN 5',
#    'period': None,
#    'note': 'Name crowd-sourced from Open Street Map.',
#    'referent': 2018,
#    'languages': [2],
#    'informants': [1]},
#   {'id': 264,
#    'created_at': '2022-11-07T13:34:37.811085Z',
#    'updated_at': '2022-11-07T13:34:37.811820Z',
#    'published': True,
#    'text': 'Rue KN 30',
#    'period': None,
#    'note': 'Name crowd-sourced from Open Street Map.',
#    'referent': 2075,
#    'languages': [2],
#    'informants': [1]},
#   {'id': 193,
#    'created_at': '2022-11-07T13:34:37.677330Z',
#    'updated_at': '2022-11-07T13:34:37.678089Z',
#    'published': True,
#    'text': 'Rue KN 139',
#    'period': None,
#    'note': 'Name crowd-sourced from Open Street Map.',
#    'referent': 2028,
#    'languages': [2],
#    'informants': [1]},
#   {'id': 277,
#    'created_at': '2022-11-07T13:34:37.835753Z',
#    'updated_at': '2022-11-07T13:34:37.836511Z',
#    'published': True,
#    'text': 'Rue KN 92',
#    'period': None,
#    'note': 'Name crowd-sourced from Open Street Map.',
#    'referent': 2084,
#    'languages': [2],
#    'informants': [1]},
#   {'id': 129,
#    'created_at': '2022-11-07T13:34:37.558216Z',
#    'updated_at': '2022-11-07T13:34:37.559013Z',
#    'published': True,
#    'text': 'Rue KN 99',
#    'period': None,
#    'note': 'Name crowd-sourced from Open Street Map.',
#    'referent': 1987,
#    'languages': [2],
#    'informants': [1]}]}

# %% [markdown]
# ## Example with parameters: Riksdagens öppna data
# The following example uses the API from Riksdagens öppna data, which does not have any documentation. The best way to learn how to use such an API is to try different parameters in the graphical interface, see https://data.riksdagen.se/dokumentlista/

# %%
base_url = "data.riksdagen.se"
endpoint_url = "dokumentlista"
url = "http://" + base_url + "/" + endpoint_url  + "/"

params = {
    'sok': 'skatt',
    'doktyp': 'mot',
    'utformat': 'json'
}

results = requests.get(url, params=params).json()

with open('data.json', 'w') as f:
    json.dump(results, f, indent=4)


results
# Out:
# {'dokumentlista': {'@ms': '39855.723',
#   '@version': '3.5.3.19619',
#   '@q': 'doktyp=mot&sok=skatt&utformat=json',
#   '@varning': 'traffar=22353',
#   '@datum': '2022-11-22 10:23:32',
#   '@nasta_sida': 'https://data.riksdagen.se/dokumentlista/?doktyp=mot&sok=skatt&utformat=json&p=2',
#   '@sida': '1',
#   '@sidor': '1118',
#   '@traff_fran': '1',
#   '@traff_till': '20',
#   '@traffar': '22353',
#   '@dPre': '0',
#   '@dSol': '46',
#   '@dDt': '0',
#   '@dR': '15',
#   'facettlista': None,
#   'dokument': [{'traff': '1',
#     'domain': 'rdwebb',
#     'database': 'dokument',
#     'datum': '2022-11-22',
#     'id': 'HA02795',
#     'rdrest': None,
#     'slutdatum': '',
#     'rddata': None,
#     'plats': '',
#     'klockslag': '',
#     'publicerad': '2022-11-22',
#     'systemdatum': '2022-11-22 09:41:10',
#     'undertitel': 'av Björn Söder (SD)',
#     'kalla': 'Filur',
#     'kall_id': '4c1b5ea5-8aec-4e83-b5af-cdd33bb5fff1',
#     'dok_id': 'HA02795',
#     'dokumentformat': '',
#     'dokument_url_text': '//data.riksdagen.se/dokument/HA02795.text',
#     'dokument_url_html': '//data.riksdagen.se/dokument/HA02795.html',
#     'inlamnad': '',
#     'motionstid': '',
#     'tilldelat': '',
#     'lang': '',
#     'url': '',
#     'relurl': '',
#     'titel': 'Uppåkra Arkeologiska Center',
#     'rm': '2022/23',
#     'organ': 'KrU',
#     'relaterat_id': '',
#     'doktyp': 'mot',
#     'typ': 'mot',
#     'subtyp': 'Kommittémotion',
#     'beteckning': '795',
#     'tempbeteckning': 'SD',
#     'nummer': '795',
#     'status': 'Granskad',
#     'score': '4887,85',
#     'sokdata': {'titel': 'Uppåkra Arkeologiska Center',
#      'undertitel': 'Motion 2022/23:795 av Björn Söder (SD)',
#      'soktyp': '',
#      'statusrad': '\n\t\t\t\t\t\t<b>Inlämnad</b>: 2022-11-22\n\t\t\t\t\t\t<b>Förslag</b>: 1',
#      'brodsmula': '',
#      'parti_kod': '',
#      'parti_namn': '',
#      'parti_website_url': '',
#      'parti_website_namn': '',
#      'parti_epost': '',
#      'parti_telefon': '',
#      'parti_logotyp_img_id': '',
#      'parti_logotyp_img_url': '',
#      'parti_logotyp_img_alt': '',
#      'parti_mandat': ''},
#     'summary': '…  vid Riksantikvarieämbetet om att fördjupa samarbetena, vilket är glädjande. Men för att vidareutveckla området och uppmärksamma den rika historiska och kulturella <span class="traff-markering">skatt</span> som vilar i den bördiga myllan kring Uppåkra kyrka, bör riksdagen tillkännage för regeringen att staten bör öka sitt intresse ännu mer för området och tillskjuta olika …',
#     'notisrubrik': 'Uppåkra Arkeologiska Center',
#     'notis': 'Motion till riksdagen\n 2022/23:795\n av Björn Söder SD Uppåkra Arkeologiska Center\n Förslag till riksdagsbeslut\n Riksdagen ställer sig bakom det som anförs i motionen om att staten bör betrakta Uppåkra Arkeologiska Center som riksintresse och tillkännager detta för regeringen. Motivering\n Fornlämningen efter järnåldersstaden',
#     'dokintressent': {'intressent': [{'roll': 'undertecknare',
#        'namn': 'Björn Söder',
#        'partibet': 'SD',
#        'intressent_id': '0452755722723'}]},
#     'filbilaga': {'fil': [{'typ': 'docx',
#        'namn': 'mot_202223__795.docx',
#        'storlek': '85120',
#        'url': 'http://data.riksdagen.se/fil/28706681-5213-4FEB-B151-1C48D939ABFF'},
#       {'typ': 'pdf',
#        'namn': 'mot_202223__795.pdf',
#        'storlek': '80704',
#        'url': 'http://data.riksdagen.se/fil/BFFF4A3F-A3A0-449D-9C01-73A823B9F01A'}]},
#     'avdelning': 'dokument',
#     'struktur': '',
#     'audio': '',
#     'video': '',
#     'debattgrupp': '',
#     'debattdag': '',
#     'beslutsdag': '',
#     'beredningsdag': '',
#     'justeringsdag': '',
#     'beslutad': '',
#     'debattsekunder': '',
#     'ardometyp': '',
#     'reservationer': '',
#     'debatt': None,
#     'debattnamn': 'Motion',
#     'dokumentnamn': 'Motion'},
#    {'traff': '2',
#     'domain': 'rdwebb',
#     'database': 'dokument',
#     'datum': '2022-11-21',
#     'id': 'HA02793',
#     'rdrest': None,
#     'slutdatum': '',
#     'rddata': None,
#     'plats': '',
#     'klockslag': '',
#     'publicerad': '2022-11-21',
#     'systemdatum': '2022-11-21 16:37:23',
#     'undertitel': 'av Peter Ollén (M)',
#     'kalla': 'Filur',
#     'kall_id': '1be2782f-05d0-44b8-b4d4-31ac7770551b',
#     'dok_id': 'HA02793',
#     'dokumentformat': '',
#     'dokument_url_text': '//data.riksdagen.se/dokument/HA02793.text',
#     'dokument_url_html': '//data.riksdagen.se/dokument/HA02793.html',
#     'inlamnad': '',
#     'motionstid': '',
#     'tilldelat': '',
#     'lang': '',
#     'url': '',
#     'relurl': '',
#     'titel': 'Skattetrappa för företagare',
#     'rm': '2022/23',
#     'organ': 'SkU',
#     'relaterat_id': '',
#     'doktyp': 'mot',
#     'typ': 'mot',
#     'subtyp': 'Enskild motion',
#     'beteckning': '793',
#     'tempbeteckning': 'M1231',
#     'nummer': '793',
#     'status': 'Granskad',
#     'score': '4887,85',
#     'sokdata': {'titel': 'Skattetrappa för företagare',
#      'undertitel': 'Motion 2022/23:793 av Peter Ollén (M)',
#      'soktyp': '',
#      'statusrad': '\n\t\t\t\t\t\t<b>Inlämnad</b>: 2022-11-21\n\t\t\t\t\t\t<b>Förslag</b>: 1',
#      'brodsmula': '',
#      'parti_kod': '',
#      'parti_namn': '',
#      'parti_website_url': '',
#      'parti_website_namn': '',
#      'parti_epost': '',
#      'parti_telefon': '',
#      'parti_logotyp_img_id': '',
#      'parti_logotyp_img_url': '',
#      'parti_logotyp_img_alt': '',
#      'parti_mandat': ''},
#     'summary': '… ställer sig bakom det som anförs i motionen om att överväga möjligheten till en skattetrappa så att nyföretagare beskattas stegvis och nya företag därför inte kvävs av <span class="traff-markering">skatter</span> innan de blivit flygfärdiga, och detta tillkännager riksdagen för regeringen. Motivering\n Majoriteten av de som flytt till Sverige kommer från länder där man har en …',
#     'notisrubrik': 'Skattetrappa för företagare',
#     'notis': 'Motion till riksdagen\n 2022/23:793\n av Peter Ollén M Skattetrappa för företagare\n Förslag till riksdagsbeslut\n Riksdagen ställer sig bakom det som anförs i motionen om att överväga möjligheten till en skattetrappa så att nyföretagare beskattas stegvis och nya företag därför inte kvävs av skatter innan de blivit flygfärdiga,',
#     'dokintressent': {'intressent': [{'roll': 'undertecknare',
#        'namn': 'Peter Ollén',
#        'partibet': 'M',
#        'intressent_id': '0191189790215'}]},
#     'filbilaga': {'fil': [{'typ': 'docx',
#        'namn': 'mot_202223__793.docx',
#        'storlek': '81305',
#        'url': 'http://data.riksdagen.se/fil/79F1DCBF-DD0F-401E-AA8A-9D3369D905B2'},
#       {'typ': 'pdf',
#        'namn': 'mot_202223__793.pdf',
#        'storlek': '69671',
#        'url': 'http://data.riksdagen.se/fil/931B150C-77E4-4AAA-8C45-E40CF464366F'}]},
#     'avdelning': 'dokument',
#     'struktur': '',
#     'audio': '',
#     'video': '',
#     'debattgrupp': '',
#     'debattdag': '',
#     'beslutsdag': '',
#     'beredningsdag': '',
#     'justeringsdag': '',
#     'beslutad': '',
#     'debattsekunder': '',
#     'ardometyp': '',
#     'reservationer': '',
#     'debatt': None,
#     'debattnamn': 'Motion',
#     'dokumentnamn': 'Motion'},
#    {'traff': '3',
#     'domain': 'rdwebb',
#     'database': 'dokument',
#     'datum': '2022-11-21',
#     'id': 'HA02792',
#     'rdrest': None,
#     'slutdatum': '',
#     'rddata': None,
#     'plats': '',
#     'klockslag': '',
#     'publicerad': '2022-11-21',
#     'systemdatum': '2022-11-21 16:39:47',
#     'undertitel': 'av Johan Hultberg (M)',
#     'kalla': 'Filur',
#     'kall_id': '2abe7c6a-f6a2-455e-8730-c16fda56bf10',
#     'dok_id': 'HA02792',
#     'dokumentformat': '',
#     'dokument_url_text': '//data.riksdagen.se/dokument/HA02792.text',
#     'dokument_url_html': '//data.riksdagen.se/dokument/HA02792.html',
#     'inlamnad': '',
#     'motionstid': '',
#     'tilldelat': '',
#     'lang': '',
#     'url': '',
#     'relurl': '',
#     'titel': 'Kommunalskatt för delårsboende',
#     'rm': '2022/23',
#     'organ': 'SkU',
#     'relaterat_id': '',
#     'doktyp': 'mot',
#     'typ': 'mot',
#     'subtyp': 'Enskild motion',
#     'beteckning': '792',
#     'tempbeteckning': 'M1020',
#     'nummer': '792',
#     'status': 'Granskad',
#     'score': '8271,746',
#     'sokdata': {'titel': 'Kommunalskatt för delårsboende',
#      'undertitel': 'Motion 2022/23:792 av Johan Hultberg (M)',
#      'soktyp': '',
#      'statusrad': '\n\t\t\t\t\t\t<b>Inlämnad</b>: 2022-11-21\n\t\t\t\t\t\t<b>Förslag</b>: 2',
#      'brodsmula': '',
#      'parti_kod': '',
#      'parti_namn': '',
#      'parti_website_url': '',
#      'parti_website_namn': '',
#      'parti_epost': '',
#      'parti_telefon': '',
#      'parti_logotyp_img_id': '',
#      'parti_logotyp_img_url': '',
#      'parti_logotyp_img_alt': '',
#      'parti_mandat': ''},
#     'summary': '… ordning där personer med dubbelt boende i hög grad nyttjar kommunal service i två kommuner men bara betalar <span class="traff-markering">skatt</span> till den ena är såväl otidsenlig som orättvis. Som ett alternativ till att låta personer med dubbelt boende betala <span class="traff-markering">skatt</span> i flera kommuner kan dagens kostnadsutjämningssystem ses över vilket är en möjlighet som skatteutskottet …',
#     'notisrubrik': 'Kommunalskatt för delårsboende',
#     'notis': 'Motion till riksdagen\n 2022/23:792\n av Johan Hultberg M Kommunalskatt för delårsboende\n Förslag till riksdagsbeslut\n Riksdagen ställer sig bakom det som anförs i motionen om att se över ifall det skulle vara möjligt att vara folkbokförd och skattskyldig i mer än en kommun och tillkännager detta för regeringen. Riksdagen',
#     'dokintressent': {'intressent': [{'roll': 'undertecknare',
#        'namn': 'Johan Hultberg',
#        'partibet': 'M',
#        'intressent_id': '069309987221'}]},
#     'filbilaga': {'fil': [{'typ': 'docx',
#        'namn': 'mot_202223__792.docx',
#        'storlek': '78612',
#        'url': 'http://data.riksdagen.se/fil/ED724C22-845F-4CB7-B93B-150E1BC0FFA6'},
#       {'typ': 'pdf',
#        'namn': 'mot_202223__792.pdf',
#        'storlek': '87067',
#        'url': 'http://data.riksdagen.se/fil/96480BC8-8EF7-4B78-9647-5BADE9C38995'}]},
#     'avdelning': 'dokument',
#     'struktur': '',
#     'audio': '',
#     'video': '',
#     'debattgrupp': '',
#     'debattdag': '',
#     'beslutsdag': '',
#     'beredningsdag': '',
#     'justeringsdag': '',
#     'beslutad': '',
#     'debattsekunder': '',
#     'ardometyp': '',
#     'reservationer': '',
#     'debatt': None,
#     'debattnamn': 'Motion',
#     'dokumentnamn': 'Motion'},
#    {'traff': '4',
#     'domain': 'rdwebb',
#     'database': 'dokument',
#     'datum': '2022-11-21',
#     'id': 'HA02791',
#     'rdrest': None,
#     'slutdatum': '',
#     'rddata': None,
#     'plats': '',
#     'klockslag': '',
#     'publicerad': '2022-11-21',
#     'systemdatum': '2022-11-21 16:41:14',
#     'undertitel': 'av Peter Ollén (M)',
#     'kalla': 'Filur',
#     'kall_id': '91e62180-f3c7-404c-b6c2-8f8231d2bb23',
#     'dok_id': 'HA02791',
#     'dokumentformat': '',
#     'dokument_url_text': '//data.riksdagen.se/dokument/HA02791.text',
#     'dokument_url_html': '//data.riksdagen.se/dokument/HA02791.html',
#     'inlamnad': '',
#     'motionstid': '',
#     'tilldelat': '',
#     'lang': '',
#     'url': '',
#     'relurl': '',
#     'titel': 'Postnords aktier i Strålfors',
#     'rm': '2022/23',
#     'organ': 'NU',
#     'relaterat_id': '',
#     'doktyp': 'mot',
#     'typ': 'mot',
#     'subtyp': 'Enskild motion',
#     'beteckning': '791',
#     'tempbeteckning': 'M1249',
#     'nummer': '791',
#     'status': 'Granskad',
#     'score': '4887,85',
#     'sokdata': {'titel': 'Postnords aktier i Strålfors',
#      'undertitel': 'Motion 2022/23:791 av Peter Ollén (M)',
#      'soktyp': '',
#      'statusrad': '\n\t\t\t\t\t\t<b>Inlämnad</b>: 2022-11-21\n\t\t\t\t\t\t<b>Förslag</b>: 1',
#      'brodsmula': '',
#      'parti_kod': '',
#      'parti_namn': '',
#      'parti_website_url': '',
#      'parti_website_namn': '',
#      'parti_epost': '',
#      'parti_telefon': '',
#      'parti_logotyp_img_id': '',
#      'parti_logotyp_img_url': '',
#      'parti_logotyp_img_alt': '',
#      'parti_mandat': ''},
#     'summary': '… Motivering\n I Skandinavien har vi många tryckerier som varje dag befinner sig på en hårt konkurrensutsatt marknad, men ändå klarar att försörja sina anställda och betala <span class="traff-markering">skatt</span> till den gemensamma välfärden. Dessa tryckerier tvingas förhålla sig till att staten, genom Postnord, äger en av aktörerna på marknaden. En aktör som dessutom får fördelar …',
#     'notisrubrik': 'Postnords aktier i Strålfors',
#     'notis': 'Motion till riksdagen\n 2022/23:791\n av Peter Ollén M Postnords aktier i Strålfors\n Förslag till riksdagsbeslut\n Riksdagen ställer sig bakom det som anförs i motionen om att se över möjligheten att sälja Postnords aktier i Strålfors och tillkännager detta för regeringen. Motivering\n I Skandinavien har vi många tryckerier',
#     'dokintressent': {'intressent': [{'roll': 'undertecknare',
#        'namn': 'Peter Ollén',
#        'partibet': 'M',
#        'intressent_id': '0191189790215'}]},
#     'filbilaga': {'fil': [{'typ': 'docx',
#        'namn': 'mot_202223__791.docx',
#        'storlek': '79292',
#        'url': 'http://data.riksdagen.se/fil/E15C098C-1183-4885-ACB6-08F2DBD39085'},
#       {'typ': 'pdf',
#        'namn': 'mot_202223__791.pdf',
#        'storlek': '67901',
#        'url': 'http://data.riksdagen.se/fil/555C0942-15CF-4163-BEC6-C7717171DA1B'}]},
#     'avdelning': 'dokument',
#     'struktur': '',
#     'audio': '',
#     'video': '',
#     'debattgrupp': '',
#     'debattdag': '',
#     'beslutsdag': '',
#     'beredningsdag': '',
#     'justeringsdag': '',
#     'beslutad': '',
#     'debattsekunder': '',
#     'ardometyp': '',
#     'reservationer': '',
#     'debatt': None,
#     'debattnamn': 'Motion',
#     'dokumentnamn': 'Motion'},
#    {'traff': '5',
#     'domain': 'rdwebb',
#     'database': 'dokument',
#     'datum': '2022-11-21',
#     'id': 'HA02770',
#     'rdrest': None,
#     'slutdatum': '',
#     'rddata': None,
#     'plats': '',
#     'klockslag': '',
#     'publicerad': '2022-11-21',
#     'systemdatum': '2022-11-21 16:31:00',
#     'undertitel': 'av Anna af Sillén (M)',
#     'kalla': 'Filur',
#     'kall_id': '9ce930d5-1127-4530-81d0-35c42573a7db',
#     'dok_id': 'HA02770',
#     'dokumentformat': '',
#     'dokument_url_text': '//data.riksdagen.se/dokument/HA02770.text',
#     'dokument_url_html': '//data.riksdagen.se/dokument/HA02770.html',
#     'inlamnad': '',
#     'motionstid': '',
#     'tilldelat': '',
#     'lang': '',
#     'url': '',
#     'relurl': '',
#     'titel': 'Ökad transparens gällande skatter',
#     'rm': '2022/23',
#     'organ': 'SkU',
#     'relaterat_id': '',
#     'doktyp': 'mot',
#     'typ': 'mot',
#     'subtyp': 'Enskild motion',
#     'beteckning': '770',
#     'tempbeteckning': 'M1222',
#     'nummer': '770',
#     'status': 'Granskad',
#     'score': '27354,393',
#     'sokdata': {'titel': 'Ökad transparens gällande skatter',
#      'undertitel': 'Motion 2022/23:770 av Anna af Sillén (M)',
#      'soktyp': '',
#      'statusrad': '\n\t\t\t\t\t\t<b>Inlämnad</b>: 2022-11-21\n\t\t\t\t\t\t<b>Förslag</b>: 1',
#      'brodsmula': '',
#      'parti_kod': '',
#      'parti_namn': '',
#      'parti_website_url': '',
#      'parti_website_namn': '',
#      'parti_epost': '',
#      'parti_telefon': '',
#      'parti_logotyp_img_id': '',
#      'parti_logotyp_img_url': '',
#      'parti_logotyp_img_alt': '',
#      'parti_mandat': ''},
#     'summary': '… inte nu. Trots att <span class="traff-markering">skatterna</span> har stor inverkan på människors ekonomi har de flesta en dålig uppfattning om <span class="traff-markering">skatternas</span> omfattning. Det gör det i praktiken lättare för politiker att höja <span class="traff-markering">skatter</span> när det i själva verket är prioriteringar och effektiviseringar som krävs. Att stärka transparensen och synliggöra dolda <span class="traff-markering">skatter</span> är angeläget. Liksom …',
#     'notisrubrik': 'Ökad transparens gällande skatter',
#     'notis': 'Motion till riksdagen\n 2022/23:770\n av Anna af Sillén M Ökad transparens gällande skatter\n Förslag till riksdagsbeslut\n Riksdagen ställer sig bakom det som anförs i motionen om att se över hur transparensen gällande skatter kan öka och tillkännager detta för regeringen. Motivering\n Vad får vi för pengarna är frågan alla',
#     'dokintressent': {'intressent': [{'roll': 'undertecknare',
#        'namn': 'Anna af Sillén',
#        'partibet': 'M',
#        'intressent_id': '0592345073323'}]},
#     'filbilaga': {'fil': [{'typ': 'docx',
#        'namn': 'mot_202223__770.docx',
#        'storlek': '82416',
#        'url': 'http://data.riksdagen.se/fil/82CCA106-1F7F-4AC7-B1F6-725A18F3EA65'},
#       {'typ': 'pdf',
#        'namn': 'mot_202223__770.pdf',
#        'storlek': '69964',
#        'url': 'http://data.riksdagen.se/fil/B72EFCAD-CE00-40BF-B44D-097D6E3EA65E'}]},
#     'avdelning': 'dokument',
#     'struktur': '',
#     'audio': '',
#     'video': '',
#     'debattgrupp': '',
#     'debattdag': '',
#     'beslutsdag': '',
#     'beredningsdag': '',
#     'justeringsdag': '',
#     'beslutad': '',
#     'debattsekunder': '',
#     'ardometyp': '',
#     'reservationer': '',
#     'debatt': None,
#     'debattnamn': 'Motion',
#     'dokumentnamn': 'Motion'},
#    {'traff': '6',
#     'domain': 'rdwebb',
#     'database': 'dokument',
#     'datum': '2022-11-21',
#     'id': 'HA02729',
#     'rdrest': None,
#     'slutdatum': '',
#     'rddata': None,
#     'plats': '',
#     'klockslag': '',
#     'publicerad': '2022-11-21',
#     'systemdatum': '2022-11-21 16:05:05',
#     'undertitel': 'av Mats Nordberg (SD)',
#     'kalla': 'Filur',
#     'kall_id': 'fe3388e9-83b0-4ac7-b620-e8eb396853f4',
#     'dok_id': 'HA02729',
#     'dokumentformat': '',
#     'dokument_url_text': '//data.riksdagen.se/dokument/HA02729.text',
#     'dokument_url_html': '//data.riksdagen.se/dokument/HA02729.html',
#     'inlamnad': '',
#     'motionstid': '',
#     'tilldelat': '',
#     'lang': '',
#     'url': '',
#     'relurl': '',
#     'titel': 'Förbättrade förutsättningar för storskalig kärnkraft',
#     'rm': '2022/23',
#     'organ': 'NU',
#     'relaterat_id': '',
#     'doktyp': 'mot',
#     'typ': 'mot',
#     'subtyp': 'Enskild motion',
#     'beteckning': '729',
#     'tempbeteckning': 'SD',
#     'nummer': '729',
#     'status': 'Granskad',
#     'score': '476,8376',
#     'sokdata': {'titel': 'Förbättrade förutsättningar för storskalig kärnkraft',
#      'undertitel': 'Motion 2022/23:729 av Mats Nordberg (SD)',
#      'soktyp': '',
#      'statusrad': '\n\t\t\t\t\t\t<b>Inlämnad</b>: 2022-11-21\n\t\t\t\t\t\t<b>Förslag</b>: 5',
#      'brodsmula': '',
#      'parti_kod': '',
#      'parti_namn': '',
#      'parti_website_url': '',
#      'parti_website_namn': '',
#      'parti_epost': '',
#      'parti_telefon': '',
#      'parti_logotyp_img_id': '',
#      'parti_logotyp_img_url': '',
#      'parti_logotyp_img_alt': '',
#      'parti_mandat': ''},
#     'summary': '… som i åratal motarbetat kärnkraften och på de regeringar som dessa partier har ingått i. Genom åratal av omväxlande nybyggnadsförbud, forskningsförbud och ensidiga <span class="traff-markering">skatter</span> och avgifter, har konstruktionen av nya reaktorer omöjliggjorts och driften av befintliga blivit allt mindre lönsam. Situationen idag är att osäkerheten kring tillgång …',
#     'notisrubrik': 'Förbättrade förutsättningar för storskalig kärnkraft',
#     'notis': 'Motion till riksdagen\n 2022/23:729\n av Mats Nordberg SD Förbättrade förutsättningar för storskalig kärnkraft\n Förslag till riksdagsbeslut\n Riksdagen ställer sig bakom det som anförs i motionen om att staten genom Vattenfall eller på annat sätt bör verka för att vara huvudägare och helst helägare av de kraftverk som Vattenfall',
#     'dokintressent': {'intressent': [{'roll': 'undertecknare',
#        'namn': 'Mats Nordberg',
#        'partibet': 'SD',
#        'intressent_id': '0365748677411'}]},
#     'filbilaga': {'fil': [{'typ': 'docx',
#        'namn': 'mot_202223__729.docx',
#        'storlek': '84482',
#        'url': 'http://data.riksdagen.se/fil/BA1E010A-8A6E-47DF-998A-3FE45C84B867'},
#       {'typ': 'pdf',
#        'namn': 'mot_202223__729.pdf',
#        'storlek': '82721',
#        'url': 'http://data.riksdagen.se/fil/CEF00193-6B4C-4D18-9F8B-35E01A621DE4'}]},
#     'avdelning': 'dokument',
#     'struktur': '',
#     'audio': '',
#     'video': '',
#     'debattgrupp': '',
#     'debattdag': '',
#     'beslutsdag': '',
#     'beredningsdag': '',
#     'justeringsdag': '',
#     'beslutad': '',
#     'debattsekunder': '',
#     'ardometyp': '',
#     'reservationer': '',
#     'debatt': None,
#     'debattnamn': 'Motion',
#     'dokumentnamn': 'Motion'},
#    {'traff': '7',
#     'domain': 'rdwebb',
#     'database': 'dokument',
#     'datum': '2022-11-21',
#     'id': 'HA02642',
#     'rdrest': None,
#     'slutdatum': '',
#     'rddata': None,
#     'plats': '',
#     'klockslag': '',
#     'publicerad': '2022-11-21',
#     'systemdatum': '2022-11-21 12:58:48',
#     'undertitel': 'av Elisabeth Thand Ringqvist och Anders W Jonsson (båda C)',
#     'kalla': 'Filur',
#     'kall_id': '7ba4df19-f8ff-47b0-8a98-f77894a15a86',
#     'dok_id': 'HA02642',
#     'dokumentformat': '',
#     'dokument_url_text': '//data.riksdagen.se/dokument/HA02642.text',
#     'dokument_url_html': '//data.riksdagen.se/dokument/HA02642.html',
#     'inlamnad': '',
#     'motionstid': '',
#     'tilldelat': '',
#     'lang': '',
#     'url': '',
#     'relurl': '',
#     'titel': 'Småskalig alkoholproduktion',
#     'rm': '2022/23',
#     'organ': 'SkU',
#     'relaterat_id': '',
#     'doktyp': 'mot',
#     'typ': 'mot',
#     'subtyp': 'Enskild motion',
#     'beteckning': '642',
#     'tempbeteckning': 'C',
#     'nummer': '642',
#     'status': 'Granskad',
#     'score': '6720,794',
#     'sokdata': {'titel': 'Småskalig alkoholproduktion',
#      'undertitel': 'Motion 2022/23:642 av Elisabeth Thand Ringqvist och Anders W Jonsson (båda C)',
#      'soktyp': '',
#      'statusrad': '\n\t\t\t\t\t\t<b>Inlämnad</b>: 2022-11-21\n\t\t\t\t\t\t<b>Förslag</b>: 1',
#      'brodsmula': '',
#      'parti_kod': '',
#      'parti_namn': '',
#      'parti_website_url': '',
#      'parti_website_namn': '',
#      'parti_epost': '',
#      'parti_telefon': '',
#      'parti_logotyp_img_id': '',
#      'parti_logotyp_img_url': '',
#      'parti_logotyp_img_alt': '',
#      'parti_mandat': ''},
#     'summary': '… bryggeriet har 20 anställda. En stor andel av bryggerierna är dessutom lokaliserade i glesbygd. En nedsatt <span class="traff-markering">skatt</span> på öl i enlighet med artikel 4 leder således inte bara till att konkurrensvillkoren utjämnas på ölmarknaden en nedsatt <span class="traff-markering">skatt</span> är dessutom ett stöd till småföretagandet i allmänhet och småföretagandet i glesbygd i synnerhet. Han …',
#     'notisrubrik': 'Småskalig alkoholproduktion',
#     'notis': 'Motion till riksdagen\n 2022/23:642\n av Elisabeth Thand Ringqvist och Anders W Jonsson båda C Småskalig alkoholproduktion\n Förslag till riksdagsbeslut\n Riksdagen ställer sig bakom det som anförs i motionen om att se över möjligheterna till förändrad beskattning av mikrobryggerier och tillkännager detta för regeringen. Motivering\n',
#     'dokintressent': {'intressent': [{'roll': 'undertecknare',
#        'namn': 'Elisabeth Thand Ringqvist',
#        'partibet': 'C',
#        'intressent_id': '0602744999917'},
#       {'roll': 'undertecknare',
#        'namn': 'Anders W Jonsson',
#        'partibet': 'C',
#        'intressent_id': '0229760896014'}]},
#     'filbilaga': {'fil': [{'typ': 'docx',
#        'namn': 'mot_202223__642.docx',
#        'storlek': '75010',
#        'url': 'http://data.riksdagen.se/fil/16CCCE92-8130-486A-9BFD-BD5BF02D842F'},
#       {'typ': 'pdf',
#        'namn': 'mot_202223__642.pdf',
#        'storlek': '83998',
#        'url': 'http://data.riksdagen.se/fil/6B6D3814-93FC-4EE7-A6B1-8C3CA45BE136'}]},
#     'avdelning': 'dokument',
#     'struktur': '',
#     'audio': '',
#     'video': '',
#     'debattgrupp': '',
#     'debattdag': '',
#     'beslutsdag': '',
#     'beredningsdag': '',
#     'justeringsdag': '',
#     'beslutad': '',
#     'debattsekunder': '',
#     'ardometyp': '',
#     'reservationer': '',
#     'debatt': None,
#     'debattnamn': 'Motion',
#     'dokumentnamn': 'Motion'},
#    {'traff': '8',
#     'domain': 'rdwebb',
#     'database': 'dokument',
#     'datum': '2022-11-21',
#     'id': 'HA02765',
#     'rdrest': None,
#     'slutdatum': '',
#     'rddata': None,
#     'plats': '',
#     'klockslag': '',
#     'publicerad': '2022-11-21',
#     'systemdatum': '2022-11-21 17:51:24',
#     'undertitel': 'av Rebecka Le Moine (MP)',
#     'kalla': 'Filur',
#     'kall_id': 'e6ee98c9-eaff-42ba-8d4d-d54d7663bb56',
#     'dok_id': 'HA02765',
#     'dokumentformat': '',
#     'dokument_url_text': '//data.riksdagen.se/dokument/HA02765.text',
#     'dokument_url_html': '//data.riksdagen.se/dokument/HA02765.html',
#     'inlamnad': '',
#     'motionstid': '',
#     'tilldelat': '',
#     'lang': '',
#     'url': '',
#     'relurl': '',
#     'titel': 'Reformering av penningsystemet',
#     'rm': '2022/23',
#     'organ': 'FiU',
#     'relaterat_id': '',
#     'doktyp': 'mot',
#     'typ': 'mot',
#     'subtyp': 'Enskild motion',
#     'beteckning': '765',
#     'tempbeteckning': 'MP1808',
#     'nummer': '765',
#     'status': 'Granskad',
#     'score': '476,8376',
#     'sokdata': {'titel': 'Reformering av penningsystemet',
#      'undertitel': 'Motion 2022/23:765 av Rebecka Le Moine (MP)',
#      'soktyp': '',
#      'statusrad': '\n\t\t\t\t\t\t<b>Inlämnad</b>: 2022-11-21\n\t\t\t\t\t\t<b>Förslag</b>: 1',
#      'brodsmula': '',
#      'parti_kod': '',
#      'parti_namn': '',
#      'parti_website_url': '',
#      'parti_website_namn': '',
#      'parti_epost': '',
#      'parti_telefon': '',
#      'parti_logotyp_img_id': '',
#      'parti_logotyp_img_url': '',
#      'parti_logotyp_img_alt': '',
#      'parti_mandat': ''},
#     'summary': '… vilket innebär att det inte längre blir lika viktigt att rädda banker vid kriser. Det räcker inte med ökad tillsyn och kontroll av bankerna, fler regler och högre <span class="traff-markering">skatter</span> och avgifter på finanssektorn för att förebygga finanskriser. Central infrastruktur som pengar ska inte drivas av privata företag med vinstintresse. Och penningmängdens …',
#     'notisrubrik': 'Reformering av penningsystemet',
#     'notis': 'Motion till riksdagen\n 2022/23:765\n av Rebecka Le Moine MP Reformering av penningsystemet\n Förslag till riksdagsbeslut\n Riksdagen ställer sig bakom det som anförs i motionen om att ge regeringen uppdraget att ta fram lämpliga åtgärder för att 9\xa0kap. 14\xa0regeringsformen ska gälla fullt ut för alla svenska pengar som skapas',
#     'dokintressent': {'intressent': [{'roll': 'undertecknare',
#        'namn': 'Rebecka Le Moine',
#        'partibet': 'MP',
#        'intressent_id': '0546731406922'}]},
#     'filbilaga': {'fil': [{'typ': 'docx',
#        'namn': 'mot_202223__765.docx',
#        'storlek': '87167',
#        'url': 'http://data.riksdagen.se/fil/2EC1635B-7211-4D1F-9C84-8DE3A4D75A0B'},
#       {'typ': 'pdf',
#        'namn': 'mot_202223__765.pdf',
#        'storlek': '88249',
#        'url': 'http://data.riksdagen.se/fil/B704BE59-981D-4060-8374-CACD37C88F73'}]},
#     'avdelning': 'dokument',
#     'struktur': '',
#     'audio': '',
#     'video': '',
#     'debattgrupp': '',
#     'debattdag': '',
#     'beslutsdag': '',
#     'beredningsdag': '',
#     'justeringsdag': '',
#     'beslutad': '',
#     'debattsekunder': '',
#     'ardometyp': '',
#     'reservationer': '',
#     'debatt': None,
#     'debattnamn': 'Motion',
#     'dokumentnamn': 'Motion'},
#    {'traff': '9',
#     'domain': 'rdwebb',
#     'database': 'dokument',
#     'datum': '2022-11-21',
#     'id': 'HA02717',
#     'rdrest': None,
#     'slutdatum': '',
#     'rddata': None,
#     'plats': '',
#     'klockslag': '',
#     'publicerad': '2022-11-21',
#     'systemdatum': '2022-11-21 15:52:15',
#     'undertitel': 'av Lina Nordquist (L)',
#     'kalla': 'Filur',
#     'kall_id': '5359827d-f074-431e-b670-de538f0f288d',
#     'dok_id': 'HA02717',
#     'dokumentformat': '',
#     'dokument_url_text': '//data.riksdagen.se/dokument/HA02717.text',
#     'dokument_url_html': '//data.riksdagen.se/dokument/HA02717.html',
#     'inlamnad': '',
#     'motionstid': '',
#     'tilldelat': '',
#     'lang': '',
#     'url': '',
#     'relurl': '',
#     'titel': 'Delårsskatt vid säsongsboende',
#     'rm': '2022/23',
#     'organ': 'SkU',
#     'relaterat_id': '',
#     'doktyp': 'mot',
#     'typ': 'mot',
#     'subtyp': 'Enskild motion',
#     'beteckning': '717',
#     'tempbeteckning': 'L',
#     'nummer': '717',
#     'status': 'Granskad',
#     'score': '7680,9077',
#     'sokdata': {'titel': 'Delårsskatt vid säsongsboende',
#      'undertitel': 'Motion 2022/23:717 av Lina Nordquist (L)',
#      'soktyp': '',
#      'statusrad': '\n\t\t\t\t\t\t<b>Inlämnad</b>: 2022-11-21\n\t\t\t\t\t\t<b>Förslag</b>: 1',
#      'brodsmula': '',
#      'parti_kod': '',
#      'parti_namn': '',
#      'parti_website_url': '',
#      'parti_website_namn': '',
#      'parti_epost': '',
#      'parti_telefon': '',
#      'parti_logotyp_img_id': '',
#      'parti_logotyp_img_url': '',
#      'parti_logotyp_img_alt': '',
#      'parti_mandat': ''},
#     'summary': '… månader i sträck någon annanstans än där de är skrivna, ofta i en älskad stuga eller åldrad släktgård. De har två boenden, men de kan med dagens regelverk bara betala <span class="traff-markering">skatt</span> i sin ena kommun. Det bör ses över om kommuner med säsongsboende invånare kan få skatteintäkter som bättre motsvarar deras faktiska kostnader och befolkningsunderlag …',
#     'notisrubrik': 'Delårsskatt vid säsongsboende',
#     'notis': 'Motion till riksdagen\n 2022/23:717\n av Lina Nordquist L Delårsskatt vid säsongsboende\n Förslag till riksdagsbeslut\n Riksdagen ställer sig bakom det som anförs i motionen om att se över möjligheterna till delårsskatt och tillkännager detta för regeringen. Motivering\n Många människor bor årligen månader i sträck någon annanstans',
#     'dokintressent': {'intressent': [{'roll': 'undertecknare',
#        'namn': 'Lina Nordquist',
#        'partibet': 'L',
#        'intressent_id': '0161616238120'}]},
#     'filbilaga': {'fil': [{'typ': 'docx',
#        'namn': 'mot_202223__717.docx',
#        'storlek': '80722',
#        'url': 'http://data.riksdagen.se/fil/FC2195D8-6313-414F-8A88-FCDC3F40BDDD'},
#       {'typ': 'pdf',
#        'namn': 'mot_202223__717.pdf',
#        'storlek': '71188',
#        'url': 'http://data.riksdagen.se/fil/43AB5B2C-6CCA-4B96-A9E3-449052F51B99'}]},
#     'avdelning': 'dokument',
#     'struktur': '',
#     'audio': '',
#     'video': '',
#     'debattgrupp': '',
#     'debattdag': '',
#     'beslutsdag': '',
#     'beredningsdag': '',
#     'justeringsdag': '',
#     'beslutad': '',
#     'debattsekunder': '',
#     'ardometyp': '',
#     'reservationer': '',
#     'debatt': None,
#     'debattnamn': 'Motion',
#     'dokumentnamn': 'Motion'},
#    {'traff': '10',
#     'domain': 'rdwebb',
#     'database': 'dokument',
#     'datum': '2022-11-21',
#     'id': 'HA02634',
#     'rdrest': None,
#     'slutdatum': '',
#     'rddata': None,
#     'plats': '',
#     'klockslag': '',
#     'publicerad': '2022-11-21',
#     'systemdatum': '2022-11-21 12:41:10',
#     'undertitel': 'av Niels Paarup-Petersen (C)',
#     'kalla': 'Filur',
#     'kall_id': 'b512d4b5-b452-499b-ac54-34476f88b745',
#     'dok_id': 'HA02634',
#     'dokumentformat': '',
#     'dokument_url_text': '//data.riksdagen.se/dokument/HA02634.text',
#     'dokument_url_html': '//data.riksdagen.se/dokument/HA02634.html',
#     'inlamnad': '',
#     'motionstid': '',
#     'tilldelat': '',
#     'lang': '',
#     'url': '',
#     'relurl': '',
#     'titel': 'En fungerande arbetsmarknad i hela Öresundsområdet',
#     'rm': '2022/23',
#     'organ': 'SkU',
#     'relaterat_id': '',
#     'doktyp': 'mot',
#     'typ': 'mot',
#     'subtyp': 'Enskild motion',
#     'beteckning': '634',
#     'tempbeteckning': 'C',
#     'nummer': '634',
#     'status': 'Granskad',
#     'score': '8671,992',
#     'sokdata': {'titel': 'En fungerande arbetsmarknad i hela Öresundsområdet',
#      'undertitel': 'Motion 2022/23:634 av Niels Paarup-Petersen (C)',
#      'soktyp': '',
#      'statusrad': '\n\t\t\t\t\t\t<b>Inlämnad</b>: 2022-11-21\n\t\t\t\t\t\t<b>Förslag</b>: 9',
#      'brodsmula': '',
#      'parti_kod': '',
#      'parti_namn': '',
#      'parti_website_url': '',
#      'parti_website_namn': '',
#      'parti_epost': '',
#      'parti_telefon': '',
#      'parti_logotyp_img_id': '',
#      'parti_logotyp_img_url': '',
#      'parti_logotyp_img_alt': '',
#      'parti_mandat': ''},
#     'summary': '… are som har jobbat hemifrån under coronapandemin kan tvingas betala <span class="traff-markering">skatt</span> i två länder. Det är följden av att de nordiska finansministrarna inte går med på ett undantag från gällande skatteregler. Enligt det nordiska skatteavtalet ska en gränspendlare betala <span class="traff-markering">skatt</span> i det land där per-sonen arbetar. Under coronapandemin har många pendlare …',
#     'notisrubrik': 'En fungerande arbetsmarknad i hela Öresundsområdet',
#     'notis': 'Motion till riksdagen\n 2022/23:634\n av Niels Paarup-Petersen C En fungerande arbetsmarknad i hela Öresundsområdet\n Förslag till riksdagsbeslut\n Riksdagen ställer sig bakom det som anförs i motionen om att säkra jämbördiga regler för gränspendlare vid uppsägning och tillkännager detta för regeringen. Riksdagen ställer sig',
#     'dokintressent': {'intressent': [{'roll': 'undertecknare',
#        'namn': 'Niels Paarup-Petersen',
#        'partibet': 'C',
#        'intressent_id': '0587736055221'}]},
#     'filbilaga': {'fil': [{'typ': 'docx',
#        'namn': 'mot_202223__634.docx',
#        'storlek': '83485',
#        'url': 'http://data.riksdagen.se/fil/C5FA1663-9A50-4FF3-824B-7D67565D26AA'},
#       {'typ': 'pdf',
#        'namn': 'mot_202223__634.pdf',
#        'storlek': '89067',
#        'url': 'http://data.riksdagen.se/fil/C6E01DD4-C333-4025-BE61-0079F4320F95'}]},
#     'avdelning': 'dokument',
#     'struktur': '',
#     'audio': '',
#     'video': '',
#     'debattgrupp': '',
#     'debattdag': '',
#     'beslutsdag': '',
#     'beredningsdag': '',
#     'justeringsdag': '',
#     'beslutad': '',
#     'debattsekunder': '',
#     'ardometyp': '',
#     'reservationer': '',
#     'debatt': None,
#     'debattnamn': 'Motion',
#     'dokumentnamn': 'Motion'},
#    {'traff': '11',
#     'domain': 'rdwebb',
#     'database': 'dokument',
#     'datum': '2022-11-21',
#     'id': 'HA02699',
#     'rdrest': None,
#     'slutdatum': '',
#     'rddata': None,
#     'plats': '',
#     'klockslag': '',
#     'publicerad': '2022-11-21',
#     'systemdatum': '2022-11-21 15:07:17',
#     'undertitel': 'av Carina Ödebrink m.fl. (S)',
#     'kalla': 'Filur',
#     'kall_id': '6cfa9de2-6c27-4230-8301-7a1aa524738e',
#     'dok_id': 'HA02699',
#     'dokumentformat': '',
#     'dokument_url_text': '//data.riksdagen.se/dokument/HA02699.text',
#     'dokument_url_html': '//data.riksdagen.se/dokument/HA02699.html',
#     'inlamnad': '',
#     'motionstid': '',
#     'tilldelat': '',
#     'lang': '',
#     'url': '',
#     'relurl': '',
#     'titel': 'Vinstjakten i skolan',
#     'rm': '2022/23',
#     'organ': 'UbU',
#     'relaterat_id': '',
#     'doktyp': 'mot',
#     'typ': 'mot',
#     'subtyp': 'Enskild motion',
#     'beteckning': '699',
#     'tempbeteckning': 'S1443',
#     'nummer': '699',
#     'status': 'Granskad',
#     'score': '4887,85',
#     'sokdata': {'titel': 'Vinstjakten i skolan',
#      'undertitel': 'Motion 2022/23:699 av Carina Ödebrink m.fl. (S)',
#      'soktyp': '',
#      'statusrad': '\n\t\t\t\t\t\t<b>Inlämnad</b>: 2022-11-21\n\t\t\t\t\t\t<b>Förslag</b>: 1',
#      'brodsmula': '',
#      'parti_kod': '',
#      'parti_namn': '',
#      'parti_website_url': '',
#      'parti_website_namn': '',
#      'parti_epost': '',
#      'parti_telefon': '',
#      'parti_logotyp_img_id': '',
#      'parti_logotyp_img_url': '',
#      'parti_logotyp_img_alt': '',
#      'parti_mandat': ''},
#     'summary': '… 6 miljarder. När medborgarna ser att de pengar de betalt för skola, vård och omsorg försvinner ner i privata plånböcker urholkas också drivkraften att vilja betala <span class="traff-markering">skatt</span>. Ett annat problem är att privatiseringarna av välfärden har segregerande effekter, exempelvis inom skolsektorn. Bland annat har det konstaterats att segregationen …',
#     'notisrubrik': 'Vinstjakten i skolan',
#     'notis': 'Motion till riksdagen\n 2022/23:699\n av Carina Ödebrink m.fl. S Vinstjakten i skolan\n Förslag till riksdagsbeslut\n Riksdagen ställer sig bakom det som anförs i motionen om att stoppa vinster i skolan och tillkännager detta för regeringen. Motivering\n En generell solidarisk finansierad välfärd som fördelas efter behov och',
#     'dokintressent': {'intressent': [{'roll': 'undertecknare',
#        'namn': 'Carina Ödebrink',
#        'partibet': 'S',
#        'intressent_id': '02910042914'},
#       {'roll': 'undertecknare',
#        'namn': 'Johanna Haraldsson',
#        'partibet': 'S',
#        'intressent_id': '0652497579621'},
#       {'roll': 'undertecknare',
#        'namn': 'Azra Muranovic',
#        'partibet': 'S',
#        'intressent_id': '0803790353229'}]},
#     'filbilaga': {'fil': [{'typ': 'docx',
#        'namn': 'mot_202223__699.docx',
#        'storlek': '74412',
#        'url': 'http://data.riksdagen.se/fil/0C809AB2-B1FF-43DA-8EE0-02EBC4712142'},
#       {'typ': 'pdf',
#        'namn': 'mot_202223__699.pdf',
#        'storlek': '81268',
#        'url': 'http://data.riksdagen.se/fil/E1725A72-0871-4EE8-9CEB-8D548855542E'}]},
#     'avdelning': 'dokument',
#     'struktur': '',
#     'audio': '',
#     'video': '',
#     'debattgrupp': '',
#     'debattdag': '',
#     'beslutsdag': '',
#     'beredningsdag': '',
#     'justeringsdag': '',
#     'beslutad': '',
#     'debattsekunder': '',
#     'ardometyp': '',
#     'reservationer': '',
#     'debatt': None,
#     'debattnamn': 'Motion',
#     'dokumentnamn': 'Motion'},
#    {'traff': '12',
#     'domain': 'rdwebb',
#     'database': 'dokument',
#     'datum': '2022-11-21',
#     'id': 'HA02747',
#     'rdrest': None,
#     'slutdatum': '',
#     'rddata': None,
#     'plats': '',
#     'klockslag': '',
#     'publicerad': '2022-11-21',
#     'systemdatum': '2022-11-21 16:36:19',
#     'undertitel': 'av Nicklas Attefjord (MP)',
#     'kalla': 'Filur',
#     'kall_id': '090dca02-e5d3-4b7f-a390-c33ec58e0624',
#     'dok_id': 'HA02747',
#     'dokumentformat': '',
#     'dokument_url_text': '//data.riksdagen.se/dokument/HA02747.text',
#     'dokument_url_html': '//data.riksdagen.se/dokument/HA02747.html',
#     'inlamnad': '',
#     'motionstid': '',
#     'tilldelat': '',
#     'lang': '',
#     'url': '',
#     'relurl': '',
#     'titel': 'Boplikt för att stärka landsbygden',
#     'rm': '2022/23',
#     'organ': 'CU',
#     'relaterat_id': '',
#     'doktyp': 'mot',
#     'typ': 'mot',
#     'subtyp': 'Enskild motion',
#     'beteckning': '747',
#     'tempbeteckning': 'MP1112',
#     'nummer': '747',
#     'status': 'Granskad',
#     'score': '4887,85',
#     'sokdata': {'titel': 'Boplikt för att stärka landsbygden',
#      'undertitel': 'Motion 2022/23:747 av Nicklas Attefjord (MP)',
#      'soktyp': '',
#      'statusrad': '\n\t\t\t\t\t\t<b>Inlämnad</b>: 2022-11-21\n\t\t\t\t\t\t<b>Förslag</b>: 1',
#      'brodsmula': '',
#      'parti_kod': '',
#      'parti_namn': '',
#      'parti_website_url': '',
#      'parti_website_namn': '',
#      'parti_epost': '',
#      'parti_telefon': '',
#      'parti_logotyp_img_id': '',
#      'parti_logotyp_img_url': '',
#      'parti_logotyp_img_alt': '',
#      'parti_mandat': ''},
#     'summary': '… människor som är åretruntboende. Idag ansvarar kommuner för samhällsplanering, va-nät, avfallshantering, omsorg och brandkår m.m. även för invånare som inte bor och betalar <span class="traff-markering">skatt</span> i kommunen. Kommuner behöver få en möjlighet att få kompensation för kostnader kopplade till fastigheter som inte är stadigvarande bostäder eller verksamheter inom …',
#     'notisrubrik': 'Boplikt för att stärka landsbygden',
#     'notis': 'Motion till riksdagen\n 2022/23:747\n av Nicklas Attefjord MP Boplikt för att stärka landsbygden\n Förslag till riksdagsbeslut\n Riksdagen ställer sig bakom det som anförs i motionen om att utreda införandet av en boplikt i Sverige på samma sätt som i våra grannländer och tillkännager detta för regeringen. Motivering\n Samhällen',
#     'dokintressent': {'intressent': [{'roll': 'undertecknare',
#        'namn': 'Nicklas Attefjord',
#        'partibet': 'MP',
#        'intressent_id': '0965245623824'}]},
#     'filbilaga': {'fil': [{'typ': 'docx',
#        'namn': 'mot_202223__747.docx',
#        'storlek': '77861',
#        'url': 'http://data.riksdagen.se/fil/87F1B08E-6EBC-41F4-972C-EC8CDF98CEE1'},
#       {'typ': 'pdf',
#        'namn': 'mot_202223__747.pdf',
#        'storlek': '78356',
#        'url': 'http://data.riksdagen.se/fil/E5B1AEFA-CF7D-4B52-8516-143C06B9A86D'}]},
#     'avdelning': 'dokument',
#     'struktur': '',
#     'audio': '',
#     'video': '',
#     'debattgrupp': '',
#     'debattdag': '',
#     'beslutsdag': '',
#     'beredningsdag': '',
#     'justeringsdag': '',
#     'beslutad': '',
#     'debattsekunder': '',
#     'ardometyp': '',
#     'reservationer': '',
#     'debatt': None,
#     'debattnamn': 'Motion',
#     'dokumentnamn': 'Motion'},
#    {'traff': '13',
#     'domain': 'rdwebb',
#     'database': 'dokument',
#     'datum': '2022-11-21',
#     'id': 'HA02745',
#     'rdrest': None,
#     'slutdatum': '',
#     'rddata': None,
#     'plats': '',
#     'klockslag': '',
#     'publicerad': '2022-11-21',
#     'systemdatum': '2022-11-21 16:36:03',
#     'undertitel': 'av Nicklas Attefjord (MP)',
#     'kalla': 'Filur',
#     'kall_id': 'cf804260-5a5f-4f28-a74e-c71f1e327f93',
#     'dok_id': 'HA02745',
#     'dokumentformat': '',
#     'dokument_url_text': '//data.riksdagen.se/dokument/HA02745.text',
#     'dokument_url_html': '//data.riksdagen.se/dokument/HA02745.html',
#     'inlamnad': '',
#     'motionstid': '',
#     'tilldelat': '',
#     'lang': '',
#     'url': '',
#     'relurl': '',
#     'titel': 'Reglering av spelmarknaden och ökat skydd för personer med spelberoende',
#     'rm': '2022/23',
#     'organ': 'KrU',
#     'relaterat_id': '',
#     'doktyp': 'mot',
#     'typ': 'mot',
#     'subtyp': 'Enskild motion',
#     'beteckning': '745',
#     'tempbeteckning': 'MP1110',
#     'nummer': '745',
#     'status': 'Granskad',
#     'score': '4887,85',
#     'sokdata': {'titel': 'Reglering av spelmarknaden och ökat skydd för personer med spelberoende',
#      'undertitel': 'Motion 2022/23:745 av Nicklas Attefjord (MP)',
#      'soktyp': '',
#      'statusrad': '\n\t\t\t\t\t\t<b>Inlämnad</b>: 2022-11-21\n\t\t\t\t\t\t<b>Förslag</b>: 5',
#      'brodsmula': '',
#      'parti_kod': '',
#      'parti_namn': '',
#      'parti_website_url': '',
#      'parti_website_namn': '',
#      'parti_epost': '',
#      'parti_telefon': '',
#      'parti_logotyp_img_id': '',
#      'parti_logotyp_img_url': '',
#      'parti_logotyp_img_alt': '',
#      'parti_mandat': ''},
#     'summary': '… jobba långsiktigt. Därför är det av stor vikt att ge föreningar som jobbar med spelberoende stabila förutsättningar. Staten tar in miljonbelopp i licensintäkter och <span class="traff-markering">skatt</span> från en bransch som likt tobak och alkoholindustrin skapar problem för de individer som utvecklar ett beroende. Sett ur detta perspektiv så bör det övervägas om mer …',
#     'notisrubrik': 'Reglering av spelmarknaden och ökat skydd för personer med spelberoende',
#     'notis': 'Motion till riksdagen\n 2022/23:745\n av Nicklas Attefjord MP Reglering av spelmarknaden och ökat skydd för personer med spelberoende\n Förslag till riksdagsbeslut\n Riksdagen ställer sig bakom det som anförs i motionen om förändringar av spelpaus och tillkännager detta för regeringen. Riksdagen ställer sig bakom det som anförs',
#     'dokintressent': {'intressent': [{'roll': 'undertecknare',
#        'namn': 'Nicklas Attefjord',
#        'partibet': 'MP',
#        'intressent_id': '0965245623824'}]},
#     'filbilaga': {'fil': [{'typ': 'docx',
#        'namn': 'mot_202223__745.docx',
#        'storlek': '83711',
#        'url': 'http://data.riksdagen.se/fil/7674ABE9-5A29-446D-9240-6BC4332F0083'},
#       {'typ': 'pdf',
#        'namn': 'mot_202223__745.pdf',
#        'storlek': '81502',
#        'url': 'http://data.riksdagen.se/fil/52AD5302-91A1-4C4F-BDD9-7DA0324E6DC3'}]},
#     'avdelning': 'dokument',
#     'struktur': '',
#     'audio': '',
#     'video': '',
#     'debattgrupp': '',
#     'debattdag': '',
#     'beslutsdag': '',
#     'beredningsdag': '',
#     'justeringsdag': '',
#     'beslutad': '',
#     'debattsekunder': '',
#     'ardometyp': '',
#     'reservationer': '',
#     'debatt': None,
#     'debattnamn': 'Motion',
#     'dokumentnamn': 'Motion'},
#    {'traff': '14',
#     'domain': 'rdwebb',
#     'database': 'dokument',
#     'datum': '2022-11-21',
#     'id': 'HA02664',
#     'rdrest': None,
#     'slutdatum': '',
#     'rddata': None,
#     'plats': '',
#     'klockslag': '',
#     'publicerad': '2022-11-21',
#     'systemdatum': '2022-11-21 14:32:39',
#     'undertitel': 'av David Josefsson (M)',
#     'kalla': 'Filur',
#     'kall_id': '13014b5a-3457-4ad5-86fb-0c68c1209d57',
#     'dok_id': 'HA02664',
#     'dokumentformat': '',
#     'dokument_url_text': '//data.riksdagen.se/dokument/HA02664.text',
#     'dokument_url_html': '//data.riksdagen.se/dokument/HA02664.html',
#     'inlamnad': '',
#     'motionstid': '',
#     'tilldelat': '',
#     'lang': '',
#     'url': '',
#     'relurl': '',
#     'titel': 'Brottsutsatta företag',
#     'rm': '2022/23',
#     'organ': 'JuU',
#     'relaterat_id': '',
#     'doktyp': 'mot',
#     'typ': 'mot',
#     'subtyp': 'Enskild motion',
#     'beteckning': '664',
#     'tempbeteckning': 'M1238',
#     'nummer': '664',
#     'status': 'Granskad',
#     'score': '4887,85',
#     'sokdata': {'titel': 'Brottsutsatta företag',
#      'undertitel': 'Motion 2022/23:664 av David Josefsson (M)',
#      'soktyp': '',
#      'statusrad': '\n\t\t\t\t\t\t<b>Inlämnad</b>: 2022-11-21\n\t\t\t\t\t\t<b>Förslag</b>: 1',
#      'brodsmula': '',
#      'parti_kod': '',
#      'parti_namn': '',
#      'parti_website_url': '',
#      'parti_website_namn': '',
#      'parti_epost': '',
#      'parti_telefon': '',
#      'parti_logotyp_img_id': '',
#      'parti_logotyp_img_url': '',
#      'parti_logotyp_img_alt': '',
#      'parti_mandat': ''},
#     'summary': '… kan också handla om oschysst konkurrens när kriminella använder till synes legala bolagsfasader för att slå ut konkurrensen i olika branscher genom att inte betala <span class="traff-markering">skatt</span>, tillämpa arbetsmiljöregler eller miljöregler och därigenom vinna affärer genom lägre priser. I undersökningen Brottslighetens kostnader 2022 från Svenskt Näringsliv …',
#     'notisrubrik': 'Brottsutsatta företag',
#     'notis': 'Motion till riksdagen\n 2022/23:664\n av David Josefsson M Brottsutsatta företag\n Förslag till riksdagsbeslut\n Riksdagen ställer sig bakom det som anförs i motionen om att regeringen bör se över möjligheterna att ge statliga myndigheter i uppdrag att kvantifiera brottslighetens kostnader för företag i syfte att lättare prioritera',
#     'dokintressent': {'intressent': [{'roll': 'undertecknare',
#        'namn': 'David Josefsson',
#        'partibet': 'M',
#        'intressent_id': '0503029811325'}]},
#     'filbilaga': {'fil': [{'typ': 'docx',
#        'namn': 'mot_202223__664.docx',
#        'storlek': '81813',
#        'url': 'http://data.riksdagen.se/fil/F2C77CA5-7CAF-408D-8FCB-F23E275F3098'},
#       {'typ': 'pdf',
#        'namn': 'mot_202223__664.pdf',
#        'storlek': '73484',
#        'url': 'http://data.riksdagen.se/fil/8F83E81F-ABDC-491F-8D65-A4539423A864'}]},
#     'avdelning': 'dokument',
#     'struktur': '',
#     'audio': '',
#     'video': '',
#     'debattgrupp': '',
#     'debattdag': '',
#     'beslutsdag': '',
#     'beredningsdag': '',
#     'justeringsdag': '',
#     'beslutad': '',
#     'debattsekunder': '',
#     'ardometyp': '',
#     'reservationer': '',
#     'debatt': None,
#     'debattnamn': 'Motion',
#     'dokumentnamn': 'Motion'},
#    {'traff': '15',
#     'domain': 'rdwebb',
#     'database': 'dokument',
#     'datum': '2022-11-18',
#     'id': 'HA02562',
#     'rdrest': None,
#     'slutdatum': '',
#     'rddata': None,
#     'plats': '',
#     'klockslag': '',
#     'publicerad': '2022-11-18',
#     'systemdatum': '2022-11-18 14:11:27',
#     'undertitel': 'av Markus Wiechel och Alexander Christiansson (båda SD)',
#     'kalla': 'Filur',
#     'kall_id': 'cdf5ee27-f50e-4800-8425-d9b59d1be5db',
#     'dok_id': 'HA02562',
#     'dokumentformat': '',
#     'dokument_url_text': '//data.riksdagen.se/dokument/HA02562.text',
#     'dokument_url_html': '//data.riksdagen.se/dokument/HA02562.html',
#     'inlamnad': '',
#     'motionstid': '',
#     'tilldelat': '',
#     'lang': '',
#     'url': '',
#     'relurl': '',
#     'titel': 'Åtgärder för en effektivare byggprocess',
#     'rm': '2022/23',
#     'organ': 'CU',
#     'relaterat_id': '',
#     'doktyp': 'mot',
#     'typ': 'mot',
#     'subtyp': 'Enskild motion',
# ...
#      'soktyp': '',
#      'statusrad': '\n\t\t\t\t\t\t<b>Inlämnad</b>: 2022-11-18\n\t\t\t\t\t\t<b>Förslag</b>: 6',
#      'brodsmula': '',
#      'parti_kod': '',
#      'parti_namn': '',
#      'parti_website_url': '',
#      'parti_website_namn': '',
#      'parti_epost': '',
#      'parti_telefon': '',
#      'parti_logotyp_img_id': '',
#      'parti_logotyp_img_url': '',
#      'parti_logotyp_img_alt': '',
#      'parti_mandat': ''},
#     'summary': '… Sverige är ett land med jämförelsevis högt skattetryck. En stor del av den <span class="traff-markering">skatt</span> som betalas in är dessutom mer eller mindre osynlig för privatpersoner. Inte heller är det särskilt lätt för enskilda att få klarhet i vad deras inbetalda <span class="traff-markering">skatt</span> går till. Eftersom <span class="traff-markering">skatt</span> inte är frivilligt att betala in kan det inte anses ligga på löntagares …',
#     'notisrubrik': 'Ett transparent skattesystem och ett ökat skydd för känsliga personuppgifter',
#     'notis': 'Motion till riksdagen\n 2022/23:559\n av Markus Wiechel SD Ett transparent skattesystem och ett ökat skydd för känsliga personuppgifter\n Förslag till riksdagsbeslut\n Riksdagen ställer sig bakom det som anförs i motionen om att se över möjligheten att tydligare redovisa mervärdesskatt för konsumenter och tillkännager detta',
#     'dokintressent': {'intressent': [{'roll': 'undertecknare',
#        'namn': 'Markus Wiechel',
#        'partibet': 'SD',
#        'intressent_id': '0204240926023'}]},
#     'filbilaga': {'fil': [{'typ': 'docx',
#        'namn': 'mot_202223__559.docx',
#        'storlek': '81849',
#        'url': 'http://data.riksdagen.se/fil/812104C9-4FD4-4E95-9759-B2B163D8B91A'},
#       {'typ': 'pdf',
#        'namn': 'mot_202223__559.pdf',
#        'storlek': '88714',
#        'url': 'http://data.riksdagen.se/fil/CFC34180-2813-4406-9609-AFEC94283FCC'}]},
#     'avdelning': 'dokument',
#     'struktur': '',
#     'audio': '',
#     'video': '',
#     'debattgrupp': '',
#     'debattdag': '',
#     'beslutsdag': '',
#     'beredningsdag': '',
#     'justeringsdag': '',
#     'beslutad': '',
#     'debattsekunder': '',
#     'ardometyp': '',
#     'reservationer': '',
#     'debatt': None,
#     'debattnamn': 'Motion',
#     'dokumentnamn': 'Motion'},
#    {'traff': '17',
#     'domain': 'rdwebb',
#     'database': 'dokument',
#     'datum': '2022-11-18',
#     'id': 'HA02482',
#     'rdrest': None,
#     'slutdatum': '',
#     'rddata': None,
#     'plats': '',
#     'klockslag': '',
#     'publicerad': '2022-11-18',
#     'systemdatum': '2022-11-18 14:39:16',
#     'undertitel': 'av Lawen Redar (S)',
#     'kalla': 'Filur',
#     'kall_id': '84b82c3b-0b6c-4791-a5fa-8c8e1bada655',
#     'dok_id': 'HA02482',
#     'dokumentformat': '',
#     'dokument_url_text': '//data.riksdagen.se/dokument/HA02482.text',
#     'dokument_url_html': '//data.riksdagen.se/dokument/HA02482.html',
#     'inlamnad': '',
#     'motionstid': '',
#     'tilldelat': '',
#     'lang': '',
#     'url': '',
#     'relurl': '',
#     'titel': 'Utveckling av den nationella planeringen av bostadspolitiken',
#     'rm': '2022/23',
#     'organ': 'CU',
#     'relaterat_id': '',
#     'doktyp': 'mot',
#     'typ': 'mot',
#     'subtyp': 'Enskild motion',
#     'beteckning': '482',
#     'tempbeteckning': 'S1266',
#     'nummer': '482',
#     'status': 'Granskad',
#     'score': '476,8376',
#     'sokdata': {'titel': 'Utveckling av den nationella planeringen av bostadspolitiken',
#      'undertitel': 'Motion 2022/23:482 av Lawen Redar (S)',
#      'soktyp': '',
#      'statusrad': '\n\t\t\t\t\t\t<b>Inlämnad</b>: 2022-11-18\n\t\t\t\t\t\t<b>Förslag</b>: 1',
#      'brodsmula': '',
#      'parti_kod': '',
#      'parti_namn': '',
#      'parti_website_url': '',
#      'parti_website_namn': '',
#      'parti_epost': '',
#      'parti_telefon': '',
#      'parti_logotyp_img_id': '',
#      'parti_logotyp_img_url': '',
#      'parti_logotyp_img_alt': '',
#      'parti_mandat': ''},
#     'summary': '… social bostadspolitik förutsätter en bättre fungerande marknad för bostadsbyggandet. Byggnormer och planeringsregler varierar över landets 290 kommuner. Därtill gynnar <span class="traff-markering">skatterna</span> ägande av det befintliga bostadsbeståndet och finansieringen av nybyggnation domineras av banksektorn och ränteläge. Det är ett fåtal aktörer som dominerar bygg- …',
#     'notisrubrik': 'Utveckling av den nationella planeringen av bostadspolitiken',
#     'notis': 'Motion till riksdagen\n 2022/23:482\n av Lawen Redar S Utveckling av den nationella planeringen av bostadspolitiken\n Förslag till riksdagsbeslut\n Riksdagen ställer sig bakom det som anförs i motionen om att utveckla en nationell planering av bostadspolitiken och tillkännager detta för regeringen. Motivering\n Det råder stor',
#     'dokintressent': {'intressent': [{'roll': 'undertecknare',
#        'namn': 'Lawen Redar',
#        'partibet': 'S',
#        'intressent_id': '037561614928'}]},
#     'filbilaga': {'fil': [{'typ': 'docx',
#        'namn': 'mot_202223__482.docx',
#        'storlek': '78649',
#        'url': 'http://data.riksdagen.se/fil/2B84D564-4CA6-456D-9C2E-303CE40B768B'},
#       {'typ': 'pdf',
#        'namn': 'mot_202223__482.pdf',
#        'storlek': '81217',
#        'url': 'http://data.riksdagen.se/fil/1458C64E-4AE6-4566-92F4-F050DB59C04D'}]},
#     'avdelning': 'dokument',
#     'struktur': '',
#     'audio': '',
#     'video': '',
#     'debattgrupp': '',
#     'debattdag': '',
#     'beslutsdag': '',
#     'beredningsdag': '',
#     'justeringsdag': '',
#     'beslutad': '',
#     'debattsekunder': '',
#     'ardometyp': '',
#     'reservationer': '',
#     'debatt': None,
#     'debattnamn': 'Motion',
#     'dokumentnamn': 'Motion'},
#    {'traff': '18',
#     'domain': 'rdwebb',
#     'database': 'dokument',
#     'datum': '2022-11-18',
#     'id': 'HA02485',
#     'rdrest': None,
#     'slutdatum': '',
#     'rddata': None,
#     'plats': '',
#     'klockslag': '',
#     'publicerad': '2022-11-18',
#     'systemdatum': '2022-11-18 13:39:02',
#     'undertitel': 'av Mattias Ottosson m.fl. (S)',
#     'kalla': 'Filur',
#     'kall_id': '5800ea08-0376-4b6a-b0c0-c592c56e70f6',
#     'dok_id': 'HA02485',
#     'dokumentformat': '',
#     'dokument_url_text': '//data.riksdagen.se/dokument/HA02485.text',
#     'dokument_url_html': '//data.riksdagen.se/dokument/HA02485.html',
#     'inlamnad': '',
#     'motionstid': '',
#     'tilldelat': '',
#     'lang': '',
#     'url': '',
#     'relurl': '',
#     'titel': 'F-skatt',
#     'rm': '2022/23',
#     'organ': 'SkU',
#     'relaterat_id': '',
#     'doktyp': 'mot',
#     'typ': 'mot',
#     'subtyp': 'Enskild motion',
#     'beteckning': '485',
#     'tempbeteckning': 'S1555',
#     'nummer': '485',
#     'status': 'Granskad',
#     'score': '27354,393',
#     'sokdata': {'titel': 'F-skatt',
#      'undertitel': 'Motion 2022/23:485 av Mattias Ottosson m.fl. (S)',
#      'soktyp': '',
#      'statusrad': '\n\t\t\t\t\t\t<b>Inlämnad</b>: 2022-11-18\n\t\t\t\t\t\t<b>Förslag</b>: 1',
#      'brodsmula': '',
#      'parti_kod': '',
#      'parti_namn': '',
#      'parti_website_url': '',
#      'parti_website_namn': '',
#      'parti_epost': '',
#      'parti_telefon': '',
#      'parti_logotyp_img_id': '',
#      'parti_logotyp_img_url': '',
#      'parti_logotyp_img_alt': '',
#      'parti_mandat': ''},
#     'summary': '… 2022/23:485\n av Mattias Ottosson m.fl. S F-<span class="traff-markering">skatt</span>\n Förslag till riksdagsbeslut\n Riksdagen ställer sig bakom det som anförs i motionen om att se över reglerna vid F-<span class="traff-markering">skatt</span> så att de inte missbrukas av oseriösa arbetsgivare och tillkännager detta för regeringen. Motivering\n För att få F-<span class="traff-markering">skatt</span> idag räcker det med att uppfylla tre kriterier …',
#     'notisrubrik': 'F-skatt',
#     'notis': 'Motion till riksdagen\n 2022/23:485\n av Mattias Ottosson m.fl. S F-skatt\n Förslag till riksdagsbeslut\n Riksdagen ställer sig bakom det som anförs i motionen om att se över reglerna vid F-skatt så att de inte missbrukas av oseriösa arbetsgivare och tillkännager detta för regeringen. Motivering\n För att få F-skatt idag räcker',
#     'dokintressent': {'intressent': [{'roll': 'undertecknare',
#        'namn': 'Mattias Ottosson',
#        'partibet': 'S',
#        'intressent_id': '0860364634014'},
#       {'roll': 'undertecknare',
#        'namn': 'Eva Lindh',
#        'partibet': 'S',
#        'intressent_id': '0780214960516'},
#       {'roll': 'undertecknare',
#        'namn': 'Johan Andersson',
#        'partibet': 'S',
#        'intressent_id': '0964730940415'},
#       {'roll': 'undertecknare',
#        'namn': 'Johan Löfstrand',
#        'partibet': 'S',
#        'intressent_id': '0612916684825'}]},
#     'filbilaga': {'fil': [{'typ': 'docx',
#        'namn': 'mot_202223__485.docx',
#        'storlek': '79536',
#        'url': 'http://data.riksdagen.se/fil/E9AE06E1-45E9-45D8-BEAB-23C90377E73E'},
#       {'typ': 'pdf',
#        'namn': 'mot_202223__485.pdf',
#        'storlek': '73289',
#        'url': 'http://data.riksdagen.se/fil/98585F2E-4B31-457B-A82E-6DFE6B4AB7AB'}]},
#     'avdelning': 'dokument',
#     'struktur': '',
#     'audio': '',
#     'video': '',
#     'debattgrupp': '',
#     'debattdag': '',
#     'beslutsdag': '',
#     'beredningsdag': '',
#     'justeringsdag': '',
#     'beslutad': '',
#     'debattsekunder': '',
#     'ardometyp': '',
#     'reservationer': '',
#     'debatt': None,
#     'debattnamn': 'Motion',
#     'dokumentnamn': 'Motion'},
#    {'traff': '19',
#     'domain': 'rdwebb',
#     'database': 'dokument',
#     'datum': '2022-11-18',
#     'id': 'HA02530',
#     'rdrest': None,
#     'slutdatum': '',
#     'rddata': None,
#     'plats': '',
#     'klockslag': '',
#     'publicerad': '2022-11-18',
#     'systemdatum': '2022-11-18 14:21:17',
#     'undertitel': 'av Ann-Sofie Lifvenhage (M)',
#     'kalla': 'Filur',
#     'kall_id': 'c148aea7-2ccd-45b4-920c-61f2e18c1fbe',
#     'dok_id': 'HA02530',
#     'dokumentformat': '',
#     'dokument_url_text': '//data.riksdagen.se/dokument/HA02530.text',
#     'dokument_url_html': '//data.riksdagen.se/dokument/HA02530.html',
#     'inlamnad': '',
#     'motionstid': '',
#     'tilldelat': '',
#     'lang': '',
#     'url': '',
#     'relurl': '',
#     'titel': 'Kompetenshöjande åtgärder via bruttolöneväxling',
#     'rm': '2022/23',
#     'organ': 'SkU',
#     'relaterat_id': '',
#     'doktyp': 'mot',
#     'typ': 'mot',
#     'subtyp': 'Enskild motion',
#     'beteckning': '530',
#     'tempbeteckning': 'M1329',
#     'nummer': '530',
#     'status': 'Granskad',
#     'score': '749,3162',
#     'sokdata': {'titel': 'Kompetenshöjande åtgärder via bruttolöneväxling',
#      'undertitel': 'Motion 2022/23:530 av Ann-Sofie Lifvenhage (M)',
#      'soktyp': '',
#      'statusrad': '\n\t\t\t\t\t\t<b>Inlämnad</b>: 2022-11-18\n\t\t\t\t\t\t<b>Förslag</b>: 1',
#      'brodsmula': '',
#      'parti_kod': '',
#      'parti_namn': '',
#      'parti_website_url': '',
#      'parti_website_namn': '',
#      'parti_epost': '',
#      'parti_telefon': '',
#      'parti_logotyp_img_id': '',
#      'parti_logotyp_img_url': '',
#      'parti_logotyp_img_alt': '',
#      'parti_mandat': ''},
#     'summary': '… som arbetsgivare. Utbildningen måste vara direkt kopplad till verksamheten för att anses vara en <span class="traff-markering">skatte</span>- och avgiftsfri förmån. Är utbildningen inte det, utan kan anses vara en generell sådan, kan den istället alltså anses vara en <span class="traff-markering">skatte</span>- och avgiftspliktig förmån som då istället ska beskattas. Samtidigt ställs det lägre skattemässiga …',
#     'notisrubrik': 'Kompetenshöjande åtgärder via bruttolöneväxling',
#     'notis': 'Motion till riksdagen\n 2022/23:530\n av Ann-Sofie Lifvenhage M Kompetenshöjande åtgärder via bruttolöneväxling\n Förslag till riksdagsbeslut\n Riksdagen ställer sig bakom det som anförs i motionen om att se över möjligheten att anställda ska kunna genomföra kompetenshöjande åtgärder via bruttolöneväxling och tillkännager detta',
#     'dokintressent': {'intressent': [{'roll': 'undertecknare',
#        'namn': 'Ann-Sofie Lifvenhage',
#        'partibet': 'M',
#        'intressent_id': '0838085832923'}]},
#     'filbilaga': {'fil': [{'typ': 'docx',
#        'namn': 'mot_202223__530.docx',
#        'storlek': '79438',
#        'url': 'http://data.riksdagen.se/fil/53D21B0C-9BC9-41AF-86CB-984195573C35'},
#       {'typ': 'pdf',
#        'namn': 'mot_202223__530.pdf',
#        'storlek': '73116',
#        'url': 'http://data.riksdagen.se/fil/0543B0B8-5BDD-4192-BC92-700074A6EAE1'}]},
#     'avdelning': 'dokument',
#     'struktur': '',
#     'audio': '',
#     'video': '',
#     'debattgrupp': '',
#     'debattdag': '',
#     'beslutsdag': '',
#     'beredningsdag': '',
#     'justeringsdag': '',
#     'beslutad': '',
#     'debattsekunder': '',
#     'ardometyp': '',
#     'reservationer': '',
#     'debatt': None,
#     'debattnamn': 'Motion',
#     'dokumentnamn': 'Motion'},
#    {'traff': '20',
#     'domain': 'rdwebb',
#     'database': 'dokument',
#     'datum': '2022-11-18',
#     'id': 'HA02528',
#     'rdrest': None,
#     'slutdatum': '',
#     'rddata': None,
#     'plats': '',
#     'klockslag': '',
#     'publicerad': '2022-11-18',
#     'systemdatum': '2022-11-18 14:15:51',
#     'undertitel': 'av Ann-Sofie Lifvenhage (M)',
#     'kalla': 'Filur',
#     'kall_id': '581a83cb-bdc3-4040-92ec-65603cd96d10',
#     'dok_id': 'HA02528',
#     'dokumentformat': '',
#     'dokument_url_text': '//data.riksdagen.se/dokument/HA02528.text',
#     'dokument_url_html': '//data.riksdagen.se/dokument/HA02528.html',
#     'inlamnad': '',
#     'motionstid': '',
#     'tilldelat': '',
#     'lang': '',
#     'url': '',
#     'relurl': '',
#     'titel': 'Synliggör skatter, moms och avgifter',
#     'rm': '2022/23',
#     'organ': 'SkU',
#     'relaterat_id': '',
#     'doktyp': 'mot',
#     'typ': 'mot',
#     'subtyp': 'Enskild motion',
#     'beteckning': '528',
#     'tempbeteckning': 'M1346',
#     'nummer': '528',
#     'status': 'Granskad',
#     'score': '27354,393',
#     'sokdata': {'titel': 'Synliggör skatter, moms och avgifter',
#      'undertitel': 'Motion 2022/23:528 av Ann-Sofie Lifvenhage (M)',
#      'soktyp': '',
#      'statusrad': '\n\t\t\t\t\t\t<b>Inlämnad</b>: 2022-11-18\n\t\t\t\t\t\t<b>Förslag</b>: 1',
#      'brodsmula': '',
#      'parti_kod': '',
#      'parti_namn': '',
#      'parti_website_url': '',
#      'parti_website_namn': '',
#      'parti_epost': '',
#      'parti_telefon': '',
#      'parti_logotyp_img_id': '',
#      'parti_logotyp_img_url': '',
#      'parti_logotyp_img_alt': '',
#      'parti_mandat': ''},
#     'summary': '… Lifvenhage M Synliggör <span class="traff-markering">skatter</span>, moms och avgifter\n Förslag till riksdagsbeslut\n Riksdagen ställer sig bakom det som anförs i motionen om att se över hur det kan förtydligas vilka <span class="traff-markering">skatter</span>, moms och avgifter som betalas på lön och köpta varor, och detta tillkännager riksdagen för regeringen. Motivering\n <span class="traff-markering">Skatter</span> på såväl lön som köpta …',
#     'notisrubrik': 'Synliggör skatter, moms och avgifter',
#     'notis': 'Motion till riksdagen\n 2022/23:528\n av Ann-Sofie Lifvenhage M Synliggör skatter, moms och avgifter\n Förslag till riksdagsbeslut\n Riksdagen ställer sig bakom det som anförs i motionen om att se över hur det kan förtydligas vilka skatter, moms och avgifter som betalas på lön och köpta varor, och detta tillkännager riksdagen',
#     'dokintressent': {'intressent': [{'roll': 'undertecknare',
#        'namn': 'Ann-Sofie Lifvenhage',
#        'partibet': 'M',
#        'intressent_id': '0838085832923'}]},
#     'filbilaga': {'fil': [{'typ': 'docx',
#        'namn': 'mot_202223__528.docx',
#        'storlek': '81547',
#        'url': 'http://data.riksdagen.se/fil/8731BE2C-9FAA-4A37-A66D-8A2BB040FF36'},
#       {'typ': 'pdf',
#        'namn': 'mot_202223__528.pdf',
#        'storlek': '69518',
#        'url': 'http://data.riksdagen.se/fil/9F48128C-F488-40C5-B3CB-638DB32CB390'}]},
#     'avdelning': 'dokument',
#     'struktur': '',
#     'audio': '',
#     'video': '',
#     'debattgrupp': '',
#     'debattdag': '',
#     'beslutsdag': '',
#     'beredningsdag': '',
#     'justeringsdag': '',
#     'beslutad': '',
#     'debattsekunder': '',
#     'ardometyp': '',
#     'reservationer': '',
#     'debatt': None,
#     'debattnamn': 'Motion',
#     'dokumentnamn': 'Motion'}]}}
